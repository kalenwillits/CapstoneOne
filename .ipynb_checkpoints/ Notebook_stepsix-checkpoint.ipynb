# %% [markdown]
# # Guided Capstone Step 6. Documentation

# %% [markdown]
# **The Data Science Method**
#
#
# 1.   Problem Identification
#
# 2.   Data Wrangling
#
# 3.   Exploratory Data Analysis
#
# 4.   Pre-processing and Training Data Development
#
# 5.  Modeling
#
# 6.   **Documentation**
#   * Review the Results
#   * Finalize Code
#   * Finalize Documentation
#   * Create a Project Report
#   * Create a Slide Deck for the Executive Audience

# %% [markdown]
# In this guided capstone we are going to revisit many of the actions we took in the previous guided capstone steps. This gives you the opportunity to practice the code you wrote to solve the questions in step 4 and 5.

# %% [markdown]
# **<font color='teal'> Start by loading the necessary packages and printing out our current working directory just to confirm we are in the correct project directory. </font>**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn import linear_model
from sklearn.metrics import explained_variance_score
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import sklearn.metrics



# !pwd
# Out:
# /media/kalen/PROJECTS/CapstoneOne

# %% [markdown]
# ## Fit Models with Training Dataset

# %% [markdown]
# **<font color='teal'> Using sklearn fit the model you chose in Guided Capstone 5 on your training dataset. This includes: creating dummy features for states if you need them, scaling the data,and creating train and test splits before fitting the chosen model.Also, remember to generate a model performance score(MAE, or explained variance) based on the testing hold-out data set.</font>**

# %% [markdown]
# ### Best Model

# %%
random_state = 1

columns_to_remove = ['Unnamed: 0', 'Unnamed: 0.1']
df = pd.read_csv('step3_output.csv')
for remove_this in columns_to_remove:
    del df[remove_this]
    
def model(df, X, y, random_state=42):
    
    
    scaler = preprocessing.StandardScaler().fit(X)
    X_scaled = scaler.transform(X)
    y = y
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=random_state)

    lm = linear_model.LinearRegression()
    model = lm.fit(X_train,y_train)

    y_pred = model.predict(X_test)

    exp_y = explained_variance_score(y_test, y_pred)
    mean_abs_y = sklearn.metrics.mean_absolute_error(y_test, y_pred)


    table['ExplainedVariance'].append(exp_y)
    table['MeanAbsoluteError'].append(mean_abs_y)

    #return pd.DataFrame(table)
    return df[y_pred]

# %% [markdown]
# ## Review the results

# %% [markdown]
# **<font color='teal'> Now, let's predict the Big Mountain Weekend price with our model in order to provide a recommendation to our managers on how to price the `AdultWeekend` lift ticket. First we need to find the row for Big Mountain resort in our data using string contains or string matching.</font>**

# %%
# df[df['Name'].str.contains('Big Mountain')]

# There is no "Big Mountain resort" in the data frame. I will continue using all data.  

print(df[df['Name'] == 'Big Mountain resort'])
# Out:
# Empty DataFrame
# Columns: [Name, state, summit_elev, vertical_drop, trams, fastEight, fastSixes, fastQuads, quad, triple, double, surface, total_chairs, Runs, TerrainParks, LongestRun_mi, SkiableTerrain_ac, Snow Making_ac, daysOpenLastYear, yearsOpen, averageSnowfall, AdultWeekday, AdultWeekend, projectedDaysOpen, NightSkiing_ac, clusters]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# **<font color='teal'> Prepare the Big Mountain resort data row as you did in the model fitting stage.</font>**

# %%
dfo = df.select_dtypes(include=['object']) # select object type columns
df = pd.concat([df.drop(dfo, axis=1), pd.get_dummies(dfo)], axis=1)

X = df.drop(['AdultWeekend'], axis=1)
y = df.AdultWeekend 
scaler = preprocessing.StandardScaler().fit(X)
X_scaled = scaler.transform(X) 
y = y
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=random_state)

lm = linear_model.LinearRegression()
model = lm.fit(X_train,y_train)

y_pred = model.predict(X_test)

exp_y = explained_variance_score(y_test, y_pred)
mean_abs_y = sklearn.metrics.mean_absolute_error(y_test, y_pred)

# %% [markdown]
# **<font color='teal'> Predict the Big Mountain resort `Adult Weekend` price and print it out.</font>** This is our expected price to present to management. Based on our model given the characteristics of the resort in comparison to other ski resorts and their unique characteristics.

# %%
#PRINTING THE AVERAGE PRICE FOR ALL RESORTS.
mean_price = df['AdultWeekend'].mean()
print("$" + str(round(mean_price, 2)))
# Out:
# $57.64

# %% [markdown]
# **<font color='teal'> Print the Big Mountain resort actual `Adult Weekend` price.</font>**

# %%
#PRINTING THE AVERAGE PREDICITON FOR ALL RESORTS.
pred_price = y_pred.mean()
print("$" + str(round(pred_price, 2)))
# Out:
# $57.15

# %% [markdown]
# **<font color='teal'> As part of reviewing the results it is an important step to generate figures to visualize the data story. We can use the clusters we added to our data frame to create scatter plots for visualizing the Adult Weekend values compared to other characteristics. Run the example below to get you started and build two or three more figures to include in your data story telling.</font>**

# %%
plt.scatter(df['summit_elev'], df['vertical_drop'], s=50, cmap='viridis', label ='clusters')
#plt.scatter(ac['summit_elev'], ac['vertical_drop'], c='black', s=100)
plt.xlabel('summit_elev')
plt.ylabel('vertical_drop')
plt.title('summit_elev by vertical_drop by cluster')
#plt.savefig('figures/fig1.png',bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'summit_elev by vertical_drop by cluster')

# %%
df['AdultWeekend'].plot(kind='hist',bins=25)
plt.xlabel('Price')
plt.title('Lift Prices Across Resorts')
plt.savefig('figures/fig2.png',bbox_inches='tight')

# %%
df_sorted = df['AdultWeekend'].sort_values().reset_index().drop('index', axis=1).plot()
plt.title('Distrobution of lift prices')
plt.ylabel('Price')
plt.savefig('figures/fig3.png',bbox_inches='tight')

# %%
y_sort = sorted(y_pred)
y_sort
plt.plot(y_sort)
plt.title('Distrobution of Predicted Lift Prices')
plt.ylabel('Price')
plt.savefig('figures/fig4.png',bbox_inches='tight')

# %%
df_project = pd.DataFrame()
df_project['Chairs'] = df['total_chairs']
df_project['DaysOpen'] = df['projectedDaysOpen']
df_project['Prices'] = df['AdultWeekend']

df_project.plot()
plt.ylabel('Value')
plt.xlabel('Observation Number')
plt.title('Exploratory Analysis')

plt.savefig('figures/fig5.png',bbox_inches='tight')

# %%
df_g = pd.DataFrame()
df_g['price'] = df['AdultWeekend']

idx = list(range(df['AdultWeekend'].count()-len(y_pred), df['AdultWeekend'].count()))

df_p = pd.DataFrame(y_pred, index=idx)
df_g['Prediction'] = df_p

df_g.plot(kind='line', subplots=True)
plt.title('Price vs Prediciton')
plt.xlabel('Observation')
plt.ylabel('Adult Weekend Price')

plt.savefig('figures/fig12png',bbox_inches='tight')

# %%
df_chairs_days = pd.DataFrame()
df_chairs_days['Chairs'] = df['total_chairs']
df_chairs_days['Prices'] = (((df['AdultWeekend']*2) + (df['AdultWeekday'])*5)/7)

df_chairs_days = df_chairs_days.sort_values(by='Chairs')
#df = df_chairs_days['Prices'].sort_values()

df_chairs_days.head()
df_chairs_days.plot(x='Chairs', y='Prices', color='teal', kind='scatter')
plt.title('Prices vs Number of Chair Lifts')

plt.savefig('figures/fig6.png',bbox_inches='tight')

# %%
df_xy = pd.DataFrame()
df_xy['Elevation'] = df['summit_elev']
df_xy['Prices'] = (((df['AdultWeekend']*2) + (df['AdultWeekday'])*5)/7)

df_xy = df_xy.sort_values(by='Elevation')
#df = df_chairs_days['Prices'].sort_values()

df_xy.head()
df_xy.plot(x='Elevation', y='Prices', color='purple', kind='scatter')
plt.title('Prices vs Summit Elevation')

plt.savefig('figures/fig7.png',bbox_inches='tight')

# %%
def compare_prices_plot(column_name, fig_num, name, kind='scatter', color='teal'):
  df_xy = pd.DataFrame()
  df_xy['column_name'] = df[column_name]
  df_xy['Prices'] = (((df['AdultWeekend']*2) + (df['AdultWeekday'])*5)/7)

  df_xy = df_xy.sort_values(by='column_name')
  df_xy.plot(x='column_name', y='Prices', color=color, kind=kind)
  plt.title('Prices vs ' + name)

  plt.savefig('figures/fig' + str(fig_num) + '.png',bbox_inches='tight')

# %%
compare_prices_plot('Runs', 8, 'Runs')

# %%
compare_prices_plot('projectedDaysOpen', 9, 'Days Open This Season', color='orange')

# %%
compare_prices_plot('Snow Making_ac', 10, 'Snow Accumulation')

# %%
compare_prices_plot('averageSnowfall', 11, 'Average Snowfall')

# %%
#Amount of ticket sales required to make back investiment.
round((1.54*10**6)/y_pred.mean())
# Out:
# 26945.0

# %%
#Amount of ticket sales required to reach goal.
round(((1.54*10**6)*1.092)/y_pred.mean())
# Out:
# 29424.0

# %% [markdown]
# ## Finalize Code

# %% [markdown]
#  Making sure our code is well organized and easy to follow is an important step. This is the time where you need to review the notebooks and Python scripts you've created and clean them up so they are easy to follow and succinct in nature. Addtionally, we will also save our final model as a callable object using Pickle for future use in a data pipeline. Pickle is a module that serializes (and de-serializes) Python objects so that they can become executable objects like functions. It's used extensively in production environments where machine learning models are deployed on an industrial scale!**<font color='teal'> Run the example code below to save out your callable model. Notice that we save it in the models folder we created in our previous guided capstone step.</font>**

# %%
import pickle
s = pickle.dumps(model)
from joblib import dump, load
dump(model, 'models/regression_model_adultweekend.joblib')
# Out:
# ['models/regression_model_adultweekend.joblib']

# %% [markdown]
# ## Finalize Documentation

# %% [markdown]
# For model documentation, we want to save the model performance metrics as well as the features included in the final model. You could also save the model perfomance metrics and coefficients fo the other models you tried in case you want to refer to them later. **<font color='teal'> Create a dataframe containing the coefficients and the model performance metrics and save it out as a csv file, then upload it to your github repository.</font>**

# %%
table_columns = ["ExplainedVariance", "MeanAbsoluteError"]
table = {}
for column_label in table_columns:
    table[column_label] = []
    
table['ExplainedVariance'].append(exp_y)
table['MeanAbsoluteError'].append(mean_abs_y)

table = pd.DataFrame(table)

# %%
table.to_csv('models/PerformanceMetrics.csv')
